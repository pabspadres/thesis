# %%
import sys
# !{sys.executable} -m pip install wikirate4py pandas openpyxl
# Out:
# Requirement already satisfied: wikirate4py in /Users/pablopadres/.pyenv/versions/3.11.8/lib/python3.11/site-packages (2.0.6)
# Requirement already satisfied: pandas in /Users/pablopadres/.pyenv/versions/3.11.8/lib/python3.11/site-packages (2.3.2)
# Requirement already satisfied: openpyxl in /Users/pablopadres/.pyenv/versions/3.11.8/lib/python3.11/site-packages (3.1.5)
# Requirement already satisfied: requests in /Users/pablopadres/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from wikirate4py) (2.32.5)
# Requirement already satisfied: html2text in /Users/pablopadres/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from wikirate4py) (2025.4.15)
# Requirement already satisfied: numpy>=1.23.2 in /Users/pablopadres/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from pandas) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/pablopadres/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/pablopadres/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/pablopadres/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: et-xmlfile in /Users/pablopadres/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: six>=1.5 in /Users/pablopadres/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/pablopadres/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from requests->wikirate4py) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/pablopadres/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from requests->wikirate4py) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/pablopadres/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from requests->wikirate4py) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/pablopadres/.pyenv/versions/3.11.8/lib/python3.11/site-packages (from requests->wikirate4py) (2025.8.3)

# %%
import wikirate4py
import pandas as pd
import numpy as np
import time
from pprint import pprint

api = wikirate4py.API("cMSYGt6SdESjs8h00EUIkwtt")

print("Imports loaded.")
# Out:
# Imports loaded.

# %%
brand_ids = [
    5505, 61104, 9410, 61050, 5800, 56013, 60982, 862441,
    60914, 116106, 116498, 2265395, 49386, 5449043,
    5448716, 5451022
]

brand_id_to_name = {
    5505: "GAP",
    61104: "VF Corp",
    9410: "Patagonia",
    61050: "PVH",
    5800: "Nike Inc.",
    56013: "New Balance",
    60982: "Hanesbrands",
    862441: "American Eagle",
    60914: "Abercrombie & Fitch",
    116106: "Fruit of the Loom",
    116498: "Under Armour",
    2265395: "Ralph Lauren",
    49386: "Tapestry",
    5449043: "Kontoor Brands",
    5448716: "Zegna",
    5451022: "Victoria’s Secret"
}

print("Total brands:", len(brand_ids))
print(brand_id_to_name)
# Out:
# Total brands: 16
# {5505: 'GAP', 61104: 'VF Corp', 9410: 'Patagonia', 61050: 'PVH', 5800: 'Nike Inc.', 56013: 'New Balance', 60982: 'Hanesbrands', 862441: 'American Eagle', 60914: 'Abercrombie & Fitch', 116106: 'Fruit of the Loom', 116498: 'Under Armour', 2265395: 'Ralph Lauren', 49386: 'Tapestry', 5449043: 'Kontoor Brands', 5448716: 'Zegna', 5451022: 'Victoria’s Secret'}

# %%
def safe_json(item):
    try:
        return item.json()
    except Exception:
        try:
            return item.__dict__
        except Exception:
            return {"raw_item": str(item)}


def pull_relationships_safe(brand_id, max_rows=2000):
    rows = []

    cursor = wikirate4py.Cursor(
        api.get_relationships,
        metric_designer="Commons",
        metric_name="Supplied By",
        subject_company_id=brand_id,
        status="exists",
        per_page=50
    )

    while cursor.has_next():
        try:
            results = cursor.next()
        except Exception as e:
            if "429" in str(e):
                print("Rate limited — sleeping 60s")
                time.sleep(2)
                continue
            else:
                raise e

        for item in results:
            rows.append(safe_json(item))

            if len(rows) >= max_rows:
                return pd.json_normalize(rows)

        time.sleep(2)

    return pd.json_normalize(rows) if rows else pd.DataFrame()


print("Helper ready.")
# Out:
# Helper ready.

# %%
relationship_batches = []

for i, brand_id in enumerate(brand_ids):
    brand_name_manual = brand_id_to_name.get(brand_id, "N/A")
    
    print(f"\nPulling {i+1}/{len(brand_ids)}: {brand_name_manual} | ID {brand_id}")
    
    try:
        temp_df = pull_relationships_safe(
            brand_id=brand_id,
            max_rows=2000
        )
        
        print(f"Rows pulled: {len(temp_df)}")
        
        if temp_df.empty:
            temp_df = pd.DataFrame([{
                "manual_brand_name": brand_name_manual,
                "manual_brand_id": brand_id,
                "missing_note": "No supplier relationships returned"
            }])
        else:
            temp_df["manual_brand_name"] = brand_name_manual
            temp_df["manual_brand_id"] = brand_id
        
        relationship_batches.append(temp_df)
        
        time.sleep(5)
        
    except Exception as e:
        print(f"ERROR for {brand_name_manual}: {e}")
        relationship_batches.append(pd.DataFrame([{
            "manual_brand_name": brand_name_manual,
            "manual_brand_id": brand_id,
            "missing_note": str(e)
        }]))

relationships_raw = pd.concat(relationship_batches, ignore_index=True)

print("\nDone.")
print("Total rows:", len(relationships_raw))
print("Columns:")
print(relationships_raw.columns.tolist())

display(relationships_raw.head().T)
# Out:
# Pulling 1/16: GAP | ID 5505
# Rows pulled: 1862
#
# Pulling 2/16: VF Corp | ID 61104
# Rows pulled: 2000
#
# Pulling 3/16: Patagonia | ID 9410
# Rows pulled: 305
#
# Pulling 4/16: PVH | ID 61050
# Rows pulled: 2000
#
# Pulling 5/16: Nike Inc. | ID 5800
# Rows pulled: 2000
#
# Pulling 6/16: New Balance | ID 56013
# Rows pulled: 996
#
# Pulling 7/16: Hanesbrands | ID 60982
# Rows pulled: 379
#
# Pulling 8/16: American Eagle | ID 862441
# Rows pulled: 1
#
# Pulling 9/16: Abercrombie & Fitch | ID 60914
# Rows pulled: 286
#
# Pulling 10/16: Fruit of the Loom | ID 116106
# Rows pulled: 595
#
# Pulling 11/16: Under Armour | ID 116498
# Rows pulled: 323
#
# Pulling 12/16: Ralph Lauren | ID 2265395
# Rows pulled: 384
#
# Pulling 13/16: Tapestry | ID 49386
# Rows pulled: 47
#
# Pulling 14/16: Kontoor Brands | ID 5449043
# Rows pulled: 876
#
# Pulling 15/16: Zegna | ID 5448716
# Rows pulled: 111
#
# Pulling 16/16: Victoria’s Secret | ID 5451022
# Rows pulled: 106
#
# Done.
# Total rows: 12271
# Columns:
# ['id', 'metric', 'metric_id', 'value', 'year', 'comments', 'sources', 'subject_company_name', 'object_company_name', 'subject_company_id', 'object_company_id', 'url', 'manual_brand_name', 'manual_brand_id']
#                                                                       0  \
# id                                                              6265767
# metric                                              Commons+Supplied By
# metric_id                                                       2929009
# value                                                   Tier 1 Supplier
# year                                                               2020
# comments
# sources                                                              []
# subject_company_name                                           Gap inc.
# object_company_name                        Alif Embroidery Village Ltd.
# subject_company_id                                                 5505
# object_company_id                                               6178119
# url                   https://wikirate.org/Commons+Supplied_By+Gap_i...
# manual_brand_name                                                   GAP
# manual_brand_id                                                    5505
#
#                                                                       1  \
# id                                                              6265773
# metric                                              Commons+Supplied By
# metric_id                                                       2929009
# value                                                   Tier 1 Supplier
# year                                                               2020
# comments
# sources                                                              []
# subject_company_name                                           Gap inc.
# object_company_name                         Ananta Denim Technology Ltd
# subject_company_id                                                 5505
# object_company_id                                               3219140
# url                   https://wikirate.org/Commons+Supplied_By+Gap_i...
# manual_brand_name                                                   GAP
# manual_brand_id                                                    5505
#
#                                                                       2  \
# id                                                              6265776
# metric                                              Commons+Supplied By
# metric_id                                                       2929009
# value                                                   Tier 1 Supplier
# year                                                               2020
# comments
# sources                                                              []
# subject_company_name                                           Gap inc.
# object_company_name                                 Ananta Garments Ltd
# subject_company_id                                                 5505
# object_company_id                                               5070765
# url                   https://wikirate.org/Commons+Supplied_By+Gap_i...
# manual_brand_name                                                   GAP
# manual_brand_id                                                    5505
#
#                                                                       3  \
# id                                                              6265779
# metric                                              Commons+Supplied By
# metric_id                                                       2929009
# value                                                   Tier 1 Supplier
# year                                                               2020
# comments
# sources                                                              []
# subject_company_name                                           Gap inc.
# object_company_name                            Colossus Apparel Limited
# subject_company_id                                                 5505
# object_company_id                                               6175881
# url                   https://wikirate.org/Commons+Supplied_By+Gap_i...
# manual_brand_name                                                   GAP
# manual_brand_id                                                    5505
#
#                                                                       4
# id                                                              6265782
# metric                                              Commons+Supplied By
# metric_id                                                       2929009
# value                                                   Tier 1 Supplier
# year                                                               2020
# comments
# sources                                                              []
# subject_company_name                                           Gap inc.
# object_company_name                     Colossus Apparel Limited unit 2
# subject_company_id                                                 5505
# object_company_id                                               3651611
# url                   https://wikirate.org/Commons+Supplied_By+Gap_i...
# manual_brand_name                                                   GAP
# manual_brand_id                                                    5505

# %%
supplier_relationships = relationships_raw[
    [
        "manual_brand_name",
        "manual_brand_id",
        "subject_company_name",
        "subject_company_id",
        "object_company_name",
        "object_company_id",
        "value",
        "year",
        "sources",
        "url"
    ]
].copy()

supplier_relationships = supplier_relationships.rename(columns={
    "manual_brand_name": "brand_name_manual",
    "manual_brand_id": "brand_id_manual",
    "subject_company_name": "brand_name_wikirate",
    "subject_company_id": "brand_id_wikirate",
    "object_company_name": "facility_name",
    "object_company_id": "facility_id",
    "value": "supplier_relationship_type",
    "url": "relationship_url"
})

supplier_relationships = supplier_relationships.replace({None: "N/A", np.nan: "N/A", "": "N/A"})

for col in supplier_relationships.columns:
    supplier_relationships[col] = supplier_relationships[col].apply(
        lambda x: str(x) if isinstance(x, (list, dict)) else x
    )

supplier_relationships = supplier_relationships.drop_duplicates()

unique_supplier_ids = (
    supplier_relationships["facility_id"]
    .replace("N/A", np.nan)
    .dropna()
    .astype(int)
    .drop_duplicates()
    .tolist()
)

print("Clean relationship rows:", len(supplier_relationships))
print("Unique supplier IDs:", len(unique_supplier_ids))
display(supplier_relationships.head())
# Out:
# Clean relationship rows: 12145
# Unique supplier IDs: 6091
#   brand_name_manual  brand_id_manual brand_name_wikirate  brand_id_wikirate  \
# 0               GAP             5505            Gap inc.               5505
# 1               GAP             5505            Gap inc.               5505
# 2               GAP             5505            Gap inc.               5505
# 3               GAP             5505            Gap inc.               5505
# 4               GAP             5505            Gap inc.               5505
#
#                      facility_name  facility_id supplier_relationship_type  \
# 0     Alif Embroidery Village Ltd.      6178119            Tier 1 Supplier
# 1      Ananta Denim Technology Ltd      3219140            Tier 1 Supplier
# 2              Ananta Garments Ltd      5070765            Tier 1 Supplier
# 3         Colossus Apparel Limited      6175881            Tier 1 Supplier
# 4  Colossus Apparel Limited unit 2      3651611            Tier 1 Supplier
#
#    year sources                                   relationship_url
# 0  2020      []  https://wikirate.org/Commons+Supplied_By+Gap_i...
# 1  2020      []  https://wikirate.org/Commons+Supplied_By+Gap_i...
# 2  2020      []  https://wikirate.org/Commons+Supplied_By+Gap_i...
# 3  2020      []  https://wikirate.org/Commons+Supplied_By+Gap_i...
# 4  2020      []  https://wikirate.org/Commons+Supplied_By+Gap_i...

# %%
test_supplier_id = unique_supplier_ids[0]

print("Testing supplier ID:", test_supplier_id)

try:
    test_company = api.get_company(test_supplier_id)
    test_data = test_company.json()
    print("Profile keys:")
    print(test_data.keys())
    pprint(test_data)
except Exception as e:
    print("get_company failed:", e)
# Out:
# Testing supplier ID: 6178119
# Profile keys:
# dict_keys(['id', 'name', 'headquarters', 'wikipedia_url', 'aliases', 'url', 'os_id', 'sec_cik', 'lei', 'isin', 'open_corporates', 'australian_business_number', 'uk_company_number'])
# {'aliases': None,
#  'australian_business_number': None,
#  'headquarters': ['Bangladesh'],
#  'id': 6178119,
#  'isin': None,
#  'lei': None,
#  'name': 'Alif Embroidery Village Ltd.',
#  'open_corporates': None,
#  'os_id': 'BD2023041JKXK29',
#  'sec_cik': None,
#  'uk_company_number': None,
#  'url': 'https://wikirate.org/Alif_Embroidery_Village_Ltd',
#  'wikipedia_url': None}

# %%
supplier_profile_rows = []

test_supplier_ids = unique_supplier_ids[:25]

for i, supplier_id in enumerate(test_supplier_ids):
    print(f"Processing {i+1}/{len(test_supplier_ids)} | Supplier ID: {supplier_id}")

    try:
        company = api.get_company(supplier_id)
        data = company.json()

        headquarters = data.get("headquarters", "N/A")

        if isinstance(headquarters, list):
            headquarters_clean = ", ".join(headquarters) if headquarters else "N/A"
        else:
            headquarters_clean = headquarters if headquarters else "N/A"

        supplier_profile_rows.append({
            "facility_id": data.get("id", supplier_id),
            "facility_name_profile": data.get("name", "N/A"),
            "headquarters": headquarters_clean,
            "supplier_profile_url": data.get("url", "N/A"),
            "os_id": data.get("os_id", "N/A")
        })

        time.sleep(1.2)

    except Exception as e:
        print(f"Error for supplier {supplier_id}: {e}")
        supplier_profile_rows.append({
            "facility_id": supplier_id,
            "facility_name_profile": "N/A",
            "headquarters": "N/A",
            "supplier_profile_url": "N/A",
            "os_id": "N/A"
        })

supplier_profiles_test = pd.DataFrame(supplier_profile_rows)

display(supplier_profiles_test.head(25))
print("Rows:", len(supplier_profiles_test))
# Out:
# Processing 1/25 | Supplier ID: 6178119
# Processing 2/25 | Supplier ID: 3219140
# Processing 3/25 | Supplier ID: 5070765
# Processing 4/25 | Supplier ID: 6175881
# Processing 5/25 | Supplier ID: 3651611
# Processing 6/25 | Supplier ID: 3457603
# Processing 7/25 | Supplier ID: 3244499
# Processing 8/25 | Supplier ID: 4712737
# Processing 9/25 | Supplier ID: 3219175
# Processing 10/25 | Supplier ID: 3451838
# Processing 11/25 | Supplier ID: 5106602
# Processing 12/25 | Supplier ID: 5022601
# Processing 13/25 | Supplier ID: 3222889
# Processing 14/25 | Supplier ID: 4713704
# Processing 15/25 | Supplier ID: 5220361
# Processing 16/25 | Supplier ID: 3438850
# Processing 17/25 | Supplier ID: 4273315
# Processing 18/25 | Supplier ID: 3250244
# Processing 19/25 | Supplier ID: 5073005
# Processing 20/25 | Supplier ID: 3438932
# Processing 21/25 | Supplier ID: 3634376
# Processing 22/25 | Supplier ID: 3634362
# Processing 23/25 | Supplier ID: 6176033
# Processing 24/25 | Supplier ID: 3439017
# Processing 25/25 | Supplier ID: 6162921
#     facility_id                             facility_name_profile  \
# 0       6178119                      Alif Embroidery Village Ltd.
# 1       3219140                       Ananta Denim Technology Ltd
# 2       5070765                               Ananta Garments Ltd
# 3       6175881                          Colossus Apparel Limited
# 4       3651611                   Colossus Apparel Limited unit 2
# 5       3457603                               Cortz Apparels Ltd.
# 6       3244499                          Creative Collection Ltd.
# 7       4712737                             CROWN WEARS (PVT) LTD
# 8       3219175                                      Denimach Ltd
# 9       3451838                                    Jeans 2000 Ltd
# 10      5106602                             MASIHATA SWEATERS LTD
# 11      5022601                                 NAFA APPARELS LTD
# 12      3222889                                  NHT Fashions Ltd
# 13      4713704                           SHAMS STYLING WEARS LTD
# 14      5220361                           Sparrow Apparel Limited
# 15      3438850                                 Pacific Jeans Ltd
# 16      4273315                              Standard (Group) Ltd
# 17      3250244                               STERLING STYLES LTD
# 18      5073005                                 Zyta Apparels Ltd
# 19      3438932                  Grace Glory Cambodia Garment Ltd
# 20      3634376  HAI LONG FAR EAST DEVELOPMENT (CAMBODIA) CO.,LTD
# 21      3634362                JINMYUNG GARMENT DEVELOPMENT CORP.
# 22      6176033                Makalot Garments(Cambodia) Co. Ltd
# 23      3439017           Morning Glory Garment Enterprise Co Ltd
# 24      6162921                            S.Y Embroidery Co. Ltd
#
#    headquarters                               supplier_profile_url  \
# 0    Bangladesh   https://wikirate.org/Alif_Embroidery_Village_Ltd
# 1    Bangladesh   https://wikirate.org/Ananta_Denim_Technology_Ltd
# 2    Bangladesh           https://wikirate.org/Ananta_Garments_Ltd
# 3    Bangladesh      https://wikirate.org/Colossus_Apparel_Limited
# 4    Bangladesh  https://wikirate.org/Colossus_Apparel_Limited_...
# 5    Bangladesh            https://wikirate.org/Cortz_Apparels_Ltd
# 6    Bangladesh       https://wikirate.org/Creative_Collection_Ltd
# 7    Bangladesh           https://wikirate.org/CROWN_WEARS_PVT_LTD
# 8    Bangladesh                  https://wikirate.org/Denimach_Ltd
# 9    Bangladesh                https://wikirate.org/Jeans_2000_Ltd
# 10   Bangladesh         https://wikirate.org/MASIHATA_SWEATERS_LTD
# 11   Bangladesh             https://wikirate.org/NAFA_APPARELS_LTD
# 12   Bangladesh              https://wikirate.org/NHT_Fashions_Ltd
# 13   Bangladesh       https://wikirate.org/SHAMS_STYLING_WEARS_LTD
# 14   Bangladesh       https://wikirate.org/Sparrow_Apparel_Limited
# 15   Bangladesh             https://wikirate.org/Pacific_Jeans_Ltd
# 16   Bangladesh            https://wikirate.org/Standard_Group_Ltd
# 17   Bangladesh           https://wikirate.org/STERLING_STYLES_LTD
# 18   Bangladesh             https://wikirate.org/Zyta_Apparels_Ltd
# 19     Cambodia  https://wikirate.org/Grace_Glory_Cambodia_Garm...
# 20     Cambodia  https://wikirate.org/HAI_LONG_FAR_EAST_DEVELOP...
# 21     Cambodia  https://wikirate.org/JINMYUNG_GARMENT_DEVELOPM...
# 22     Cambodia  https://wikirate.org/Makalot_Garments_Cambodia...
# 23     Cambodia  https://wikirate.org/Morning_Glory_Garment_Ent...
# 24     Cambodia         https://wikirate.org/S_Y_Embroidery_Co_Ltd
#
#               os_id
# 0   BD2023041JKXK29
# 1   BD20190863HNZEP
# 2   BD2021341C364T6
# 3   BD2019091ZKVVVZ
# 4   BD2019091ZKVVVZ
# 5   BD2021333FKGAS9
# 6   BD2019133KEDYTZ
# 7   BD2019083X6XXGA
# 8   BD20190863XSXH7
# 9   BD20191085S9C5K
# 10  BD20190853EMPB5
# 11  BD2019086XWZET0
# 12  BD2019083Z4RT0J
# 13  BD20191089C8D5A
# 14             None
# 15  BD2019091A16MXY
# 16  BD2019108MK0RGA
# 17  BD2019083RWG6PX
# 18  BD2019083GJ5H2Q
# 19  KH2019181BEMPYA
# 20  KH2019083ACT6QQ
# 21  KH2019087PGPGPG
# 22  KH2019108NATSE8
# 23  KH2019083YWV1CC
# 24  KH20190862TV35C
# Rows: 25

# %%
supplier_profile_rows = []

for i, supplier_id in enumerate(unique_supplier_ids):
    if i % 100 == 0:
        print(f"Processing {i+1}/{len(unique_supplier_ids)}")

    try:
        company = api.get_company(supplier_id)
        data = company.json()

        headquarters = data.get("headquarters", "N/A")

        if isinstance(headquarters, list):
            headquarters_clean = ", ".join(headquarters) if headquarters else "N/A"
        else:
            headquarters_clean = headquarters if headquarters else "N/A"

        supplier_profile_rows.append({
            "facility_id": data.get("id", supplier_id),
            "facility_name_profile": data.get("name", "N/A"),
            "headquarters": headquarters_clean,
            "supplier_profile_url": data.get("url", "N/A"),
            "os_id": data.get("os_id", "N/A")
        })

    except Exception as e:
        print(f"Error for supplier {supplier_id}: {e}")
        supplier_profile_rows.append({
            "facility_id": supplier_id,
            "facility_name_profile": "N/A",
            "headquarters": "N/A",
            "supplier_profile_url": "N/A",
            "os_id": "N/A"
        })

    if (i + 1) % 500 == 0:
        checkpoint_df = pd.DataFrame(supplier_profile_rows)
        checkpoint_df.to_excel(f"supplier_profiles_checkpoint_{i+1}.xlsx", index=False)
        print(f"Checkpoint saved at {i+1} suppliers")

    time.sleep(1.1)

supplier_profiles = pd.DataFrame(supplier_profile_rows)

supplier_profiles.to_excel("supplier_profiles_full.xlsx", index=False)

print("Done.")
print("Supplier profile rows:", len(supplier_profiles))
display(supplier_profiles.head())
# Out:
# Processing 1/6091
# Processing 101/6091
# Processing 201/6091
# Processing 301/6091
# Processing 401/6091
# Checkpoint saved at 500 suppliers
# Processing 501/6091
# Processing 601/6091
# Processing 701/6091
# Processing 801/6091
# Processing 901/6091
# Checkpoint saved at 1000 suppliers
# Processing 1001/6091
# Processing 1101/6091
# Processing 1201/6091
# Processing 1301/6091
# Processing 1401/6091
# Checkpoint saved at 1500 suppliers
# Processing 1501/6091
# Processing 1601/6091
# Processing 1701/6091
# Processing 1801/6091
# Processing 1901/6091
# Checkpoint saved at 2000 suppliers
# Processing 2001/6091
# Processing 2101/6091
# Processing 2201/6091
# Processing 2301/6091
# Processing 2401/6091
# Checkpoint saved at 2500 suppliers
# Processing 2501/6091
# Processing 2601/6091
# Processing 2701/6091
# Processing 2801/6091
# Processing 2901/6091
# Checkpoint saved at 3000 suppliers
# Processing 3001/6091
# Error for supplier 7287063: list index out of range
# Processing 3101/6091
# Processing 3201/6091
# Processing 3301/6091
# Processing 3401/6091
# Checkpoint saved at 3500 suppliers
# Processing 3501/6091
# Processing 3601/6091
# Processing 3701/6091
# Processing 3801/6091
# Processing 3901/6091
# Error for supplier 6204255: list index out of range
# Checkpoint saved at 4000 suppliers
# Processing 4001/6091
# Processing 4101/6091
# Processing 4201/6091
# Processing 4301/6091
# Processing 4401/6091
# Checkpoint saved at 4500 suppliers
# Processing 4501/6091
# Processing 4601/6091
# Processing 4701/6091
# Processing 4801/6091
# Processing 4901/6091
# Checkpoint saved at 5000 suppliers
# Processing 5001/6091
# Processing 5101/6091
# Processing 5201/6091
# Processing 5301/6091
# Processing 5401/6091
# Checkpoint saved at 5500 suppliers
# Processing 5501/6091
# Processing 5601/6091
# Processing 5701/6091
# Processing 5801/6091
# Processing 5901/6091
# Checkpoint saved at 6000 suppliers
# Processing 6001/6091
# Done.
# Supplier profile rows: 6091
#    facility_id            facility_name_profile headquarters  \
# 0      6178119     Alif Embroidery Village Ltd.   Bangladesh
# 1      3219140      Ananta Denim Technology Ltd   Bangladesh
# 2      5070765              Ananta Garments Ltd   Bangladesh
# 3      6175881         Colossus Apparel Limited   Bangladesh
# 4      3651611  Colossus Apparel Limited unit 2   Bangladesh
#
#                                 supplier_profile_url            os_id
# 0   https://wikirate.org/Alif_Embroidery_Village_Ltd  BD2023041JKXK29
# 1   https://wikirate.org/Ananta_Denim_Technology_Ltd  BD20190863HNZEP
# 2           https://wikirate.org/Ananta_Garments_Ltd  BD2021341C364T6
# 3      https://wikirate.org/Colossus_Apparel_Limited  BD2019091ZKVVVZ
# 4  https://wikirate.org/Colossus_Apparel_Limited_...  BD2019091ZKVVVZ

# %%
supplier_network = supplier_relationships.merge(
    supplier_profiles,
    on="facility_id",
    how="left"
)

supplier_network["headquarters"] = supplier_network["headquarters"].replace({
    None: "N/A",
    np.nan: "N/A",
    "": "N/A"
})

display(supplier_network.head())

print("Rows:", len(supplier_network))
print("Unique brands:", supplier_network["brand_name_manual"].nunique())
print("Unique facilities:", supplier_network["facility_id"].nunique())
print("Rows missing headquarters:", (supplier_network["headquarters"] == "N/A").sum())
# Out:
#   brand_name_manual  brand_id_manual brand_name_wikirate  brand_id_wikirate  \
# 0               GAP             5505            Gap inc.               5505
# 1               GAP             5505            Gap inc.               5505
# 2               GAP             5505            Gap inc.               5505
# 3               GAP             5505            Gap inc.               5505
# 4               GAP             5505            Gap inc.               5505
#
#                      facility_name  facility_id supplier_relationship_type  \
# 0     Alif Embroidery Village Ltd.      6178119            Tier 1 Supplier
# 1      Ananta Denim Technology Ltd      3219140            Tier 1 Supplier
# 2              Ananta Garments Ltd      5070765            Tier 1 Supplier
# 3         Colossus Apparel Limited      6175881            Tier 1 Supplier
# 4  Colossus Apparel Limited unit 2      3651611            Tier 1 Supplier
#
#    year sources                                   relationship_url  \
# 0  2020      []  https://wikirate.org/Commons+Supplied_By+Gap_i...
# 1  2020      []  https://wikirate.org/Commons+Supplied_By+Gap_i...
# 2  2020      []  https://wikirate.org/Commons+Supplied_By+Gap_i...
# 3  2020      []  https://wikirate.org/Commons+Supplied_By+Gap_i...
# 4  2020      []  https://wikirate.org/Commons+Supplied_By+Gap_i...
#
#              facility_name_profile headquarters  \
# 0     Alif Embroidery Village Ltd.   Bangladesh
# 1      Ananta Denim Technology Ltd   Bangladesh
# 2              Ananta Garments Ltd   Bangladesh
# 3         Colossus Apparel Limited   Bangladesh
# 4  Colossus Apparel Limited unit 2   Bangladesh
#
#                                 supplier_profile_url            os_id
# 0   https://wikirate.org/Alif_Embroidery_Village_Ltd  BD2023041JKXK29
# 1   https://wikirate.org/Ananta_Denim_Technology_Ltd  BD20190863HNZEP
# 2           https://wikirate.org/Ananta_Garments_Ltd  BD2021341C364T6
# 3      https://wikirate.org/Colossus_Apparel_Limited  BD2019091ZKVVVZ
# 4  https://wikirate.org/Colossus_Apparel_Limited_...  BD2019091ZKVVVZ
# Rows: 12145
# Unique brands: 16
# Unique facilities: 6091
# Rows missing headquarters: 162

# %%
supplier_network_clean = supplier_network[
    [
        "brand_name_manual",
        "brand_id_manual",
        "brand_name_wikirate",
        "facility_name",
        "facility_id",
        "headquarters",
        "year",
        "supplier_relationship_type",
        "relationship_url",
        "supplier_profile_url",
        "os_id"
    ]
].copy()

supplier_network_clean = supplier_network_clean.rename(columns={
    "brand_name_manual": "brand",
    "brand_id_manual": "brand_id",
    "brand_name_wikirate": "brand_wikirate_name",
    "headquarters": "country"
})

supplier_network_clean = supplier_network_clean.replace({
    None: "N/A",
    np.nan: "N/A",
    "": "N/A"
})

display(supplier_network_clean.head())
print("Rows:", len(supplier_network_clean))
print("Missing country:", (supplier_network_clean["country"] == "N/A").sum())
# Out:
#   brand  brand_id brand_wikirate_name                    facility_name  \
# 0   GAP      5505            Gap inc.     Alif Embroidery Village Ltd.
# 1   GAP      5505            Gap inc.      Ananta Denim Technology Ltd
# 2   GAP      5505            Gap inc.              Ananta Garments Ltd
# 3   GAP      5505            Gap inc.         Colossus Apparel Limited
# 4   GAP      5505            Gap inc.  Colossus Apparel Limited unit 2
#
#    facility_id     country  year supplier_relationship_type  \
# 0      6178119  Bangladesh  2020            Tier 1 Supplier
# 1      3219140  Bangladesh  2020            Tier 1 Supplier
# 2      5070765  Bangladesh  2020            Tier 1 Supplier
# 3      6175881  Bangladesh  2020            Tier 1 Supplier
# 4      3651611  Bangladesh  2020            Tier 1 Supplier
#
#                                     relationship_url  \
# 0  https://wikirate.org/Commons+Supplied_By+Gap_i...
# 1  https://wikirate.org/Commons+Supplied_By+Gap_i...
# 2  https://wikirate.org/Commons+Supplied_By+Gap_i...
# 3  https://wikirate.org/Commons+Supplied_By+Gap_i...
# 4  https://wikirate.org/Commons+Supplied_By+Gap_i...
#
#                                 supplier_profile_url            os_id
# 0   https://wikirate.org/Alif_Embroidery_Village_Ltd  BD2023041JKXK29
# 1   https://wikirate.org/Ananta_Denim_Technology_Ltd  BD20190863HNZEP
# 2           https://wikirate.org/Ananta_Garments_Ltd  BD2021341C364T6
# 3      https://wikirate.org/Colossus_Apparel_Limited  BD2019091ZKVVVZ
# 4  https://wikirate.org/Colossus_Apparel_Limited_...  BD2019091ZKVVVZ
# Rows: 12145
# Missing country: 162

# %%
supplier_network_clean.to_excel(
    "brand_supplier_country_network_final.xlsx",
    index=False
)

print("Export complete.")
# Out:
# Export complete.
